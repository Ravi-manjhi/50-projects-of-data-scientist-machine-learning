# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Downloading data from kaggle

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d mathurinache/world-happiness-report

# %%
!  unzip /content/world-happiness-report.zip

# %%
! rm /content/world-happiness-report.zip

# %% [markdown]
# # Data Pre-processing

# %%
df = pd.read_csv('./2022.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.dropna(inplace=True)

# %%
all_object = ['Happiness score', 'Whisker-high', 'Whisker-low',
       'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
       'Explained by: Social support', 'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption']

for i in all_object:
  df[i] = df[i].apply(lambda x: x.replace(',', '.'))
  df[i] = df[i].astype('float64')

# %%
plt.figure(figsize=(15, 12), dpi=120)
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.describe()

# %%
df.head()

# %%
df[df['Country']== 'India']

# %%
sns.lmplot(data=df, x='RANK', y='Explained by: GDP per capita')
plt.show()

# %%
sns.regplot(data=df, y='Happiness score', x='Explained by: Healthy life expectancy')
plt.show()

# %%
sns.boxplot(data=df, x='Happiness score', y='Explained by: Healthy life expectancy')
plt.show()

# %%
x = df[['Happiness score', 'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
       'Explained by: Social support', 'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption']]

# %%
y = df[['RANK']].values

# %%
# standard the data
scaler = StandardScaler().fit(x)
x = scaler.transform(x)

# %%
model = LinearRegression()

# %%
model.fit(x, y)

# %%
model.score(x, y)

# %%
model_ = DecisionTreeRegressor().fit(x, y)

# %%
model_.score(x, y)

# %%
3
