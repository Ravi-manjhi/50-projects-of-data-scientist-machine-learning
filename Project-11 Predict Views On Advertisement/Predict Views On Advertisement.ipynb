# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, log_loss
import xgboost as xgb
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv('./advertising.csv')

# %%
df.shape

# %%
df.info()

# %%
df.head()

# %%
x = df.drop(["Ad Topic Line", "City", "Country", "Timestamp", "Clicked on Ad"], axis=1)
y = df['Clicked on Ad'].values

# %%
sc = StandardScaler().fit(x)
x = sc.transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)

# %% [markdown]
# ## building model

# %%
model = xgb.XGBClassifier()

# %%
model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_pred, y_test)

# %%
print(classification_report(y_pred, y_test))

# %%
print(log_loss(y_test, y_pred))

# %% [markdown]
# ## sklearn model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_ = LogisticRegression()

# %%
model_.fit(x_train, y_train)

# %%
model_.score(x_train, y_train)

# %%
y_pred_logi = model_.predict(x_test)

# %%
print("The Score of Logistic Regression", accuracy_score(y_pred_logi, y_test))

# %%
print(classification_report(y_pred_logi, y_test))

# %%
print(log_loss(y_test, y_pred_logi))

# %% [markdown]
# # svm model

# %%
model_svc = SVC()

# %%
model_svc.fit(x_train, y_train)

# %%
model_svc.score(x_train, y_train)

# %%
y_pred_svc = model_svc.predict(x_test)

# %%
print('The Score of svc Model is ', accuracy_score(y_test, y_pred_svc))

# %%
print(classification_report(y_test, y_pred_svc))

# %%
print('The Log_loss', log_loss(y_test, y_pred_svc))

# %% [markdown]
# ## Decision Tree Classifier

# %%
model_tc = DecisionTreeClassifier(criterion='entropy')

# %%
model_tc.fit(x_train, y_train)

# %%
model_tc.score(x_train, y_train)

# %%
y_pred_tc = model_tc.predict(x_test)

# %%
print("the Decision Tree Classifier score", accuracy_score(y_test, y_pred_tc))

# %%
print("the Log_loss score", log_loss(y_test, y_pred_tc))

# %% [markdown]
# ## LGBMClassifier

# %%
model_lgbm = LGBMClassifier()

# %%
model_lgbm.fit(x_train, y_train)

# %%
model_lgbm.score(x_train,y_train)

# %%
y_pred_lg = model_lgbm.predict(x_test)

# %%
print('LGBM Classification score is', accuracy_score(y_test, y_pred_lg))

# %%
print("the Log loss score is", log_loss(y_test, y_pred_lg))
